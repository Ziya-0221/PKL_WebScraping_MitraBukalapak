# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import requests
import pandas as pd

# url = 'https://api.bukalapak.com/phone-credits/prepaid-products'
url = 'https://api.bukalapak.com/phone-credits/prepaid-products?category=package&group=agent&access_token=P0SHC2u7qRCPvLXI1hS8m4GV-1gY1pg_ZpVCfnOYvOW-tg'

payload = {'category':'package',
            'group': 'agent',
            'access_token': '5V3Ka8nNI9sprZ5katKKZP7AUsh-dSKEgjchEzbOS14Ybw'}

headers = {
    'authority': 'api.bukalapak.com',
    'method': 'GET',
    'path': '/phone-credits/prepaid-products?category=package&group=agent&access_token=P0SHC2u7qRCPvLXI1hS8m4GV-1gY1pg_ZpVCfnOYvOW-tg',
    'accept': 'application/vnd.bukalapak.v4+json',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'id-ID,id;q=0.9,en-US;q=0.8,en;q=0.7',
    'content-type': 'application/json',
    'origin': 'https://mitra.bukalapak.com',
    'referer': 'https://mitra.bukalapak.com/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'
}

res = requests.get( url, headers=headers, params=payload).json()
# print(res)

no = []
operators = []
products = []
descs = []
normalPrices = []
prices = []
disct = []

datas = res['data']
for data in datas:
    operator     = data['operator']['name']
    product      = data['name']
    desc         = data['description']
    normal_price = data['partner_package']['package']['normal_price']
    price        = data['partner_package']['package']['price']
    discount     = data['partner_package']['package']['discount']
    
#     no.append(count)
    operators.append(operator)
    products.append(product)
    descs.append(desc)
    normalPrices.append(normal_price)
    prices.append(price)
    disct.append(discount)
    
count = range(1, len(operators)+1)
no.extend(count)

# print(len(disct))
    
df = pd.DataFrame({
    'No':no,
    'Operator':operators,
    'Product':products,
    'Description':descs,
    'Normal Price': normalPrices,
    'Price': prices,
    'Discount':disct
    })
df.to_csv('paket_data.csv', index=False)
print(df)
    
#     print(operator)
# Out:
#       No   Operator                                  Product  \
# 0      1         XL             Xtra Hotrod Special 2GB, 7hr
# 1      2         XL             Xtra Hotrod Special 3GB, 7hr
# 2      3       Axis                 BRONET Mini 1.5GB 7 hari
# 3      4  Telkomsel           Telkomsel Data Flash 1GB, 30Hr
# 4      5       Axis                   BRONET Mini 2GB 7 hari
# ..   ...        ...                                      ...
# 248  249    Indosat             Freedom Combo 60GB / 30 Hari
# 249  250         XL            Paket Internet XL HotRod 12GB
# 250  251  Telkomsel         PAKET INTERNET BULANAN OMG! 210K
# 251  252         XL            Paket Internet XL HotRod 16GB
# 252  253         XL  Paket Akrab 460GB + Bonus Pulsa 100.000
#
#                                            Description  Normal Price   Price  \
# 0    Kuota Utama 500MB + Kuota Area hingga 3.5GB + ...         11941   11200
# 1    Kuota Utama 1GB + Kuota Area hingga 6GB + YouT...         14889   14000
# 2    Kuota Internet 1.5GB berlaku di semua Jaringan...         14850   13973
# 3                  Kuota utama 1GB, masa aktif 30 Hari         24280   23550
# 4    Kuota Internet 2GB berlaku di semua Jaringan 2...         18849   16357
# ..                                                 ...           ...     ...
# 248  • Kuota Utama 45GB+Kuota Malam 15GB. • Baru! K...        162600  162600
# 249   Kuota Utama 12GB (2G/3G/4G). Masa aktif 30 hari.        175895  175895
# 250                      KUOTA 43GB sd 83GB + 2GB OMG!        217025  217025
# 251   Kuota Utama 16GB (2G/3G/4G). Masa aktif 30 hari.        215000  215000
# 252  160GB Kuota Bersama + Bonus Kuota Pribadi hing...        515000  515000
#
#      Discount
# 0         741
# 1         889
# 2         877
# 3         730
# 4        2492
# ..        ...
# 248         0
# 249      4105
# 250         0
# 251      5000
# 252         0
#
# [253 rows x 7 columns]
